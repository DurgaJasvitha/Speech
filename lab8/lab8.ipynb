# %%
import librosa
import librosa.display
import IPython.display as ipd
from IPython.display import Audio
from itertools import cycle

# %%
y,sr= librosa.load(r"C:\Users\jasvi\Downloads\speechsignal.wav")

# %%
librosa.display.waveshow(y)

# %%
sr
# Out:
# 22050

# %%
import numpy as np
import librosa

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, TimeDistributed
from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From C:\Users\jasvi\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
n_mfcc=13

# %%
def extract_features(file_path):
    y, sr = librosa.load(file_path, sr=None)
  
    features = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    print(list(features))
    return list(features)

# %%
file_path = r"C:\Users\jasvi\OneDrive\Desktop\sem6\sp\lab8"
labels = ['a','e','i','o','c','h','s']  # List of labels
features = []  # List of extracted features

# %%
for label in labels:
        feature = extract_features(file_path+"/"+label+".wav")
        
        features.append(feature)
# Out:
# [array([-569.0172 , -569.0172 , -569.0172 , -569.0172 , -569.0172 ,
#        -569.0172 , -569.0172 , -569.0172 , -486.29343, -410.32568,
#        -385.73798, -373.7742 , -357.4807 , -349.26624, -349.50208,
#        -348.62686, -347.5869 , -338.31754, -335.19467, -342.5319 ,
#        -346.46796, -342.77106, -339.88583, -338.46454, -341.0362 ,
#        -342.53632, -336.38995, -337.3898 , -334.79956, -332.82468,
#        -331.1256 , -326.79385, -323.389  , -312.89047, -304.27026,
#        -296.86713, -294.14816, -296.4771 , -297.89203, -296.7298 ,
#        -298.4574 , -303.95206, -306.78522, -304.55096, -304.7023 ,
#        -303.7097 , -303.8115 , -305.77737, -307.07797, -307.66782,
#        -309.10025, -298.4072 , -292.9073 , -302.32465, -312.00418,
#        -301.569  , -290.34018, -291.67212, -299.97824, -300.91678,
#        -297.71844, -304.83417, -300.32544, -295.2486 , -298.58484,
#        -305.01813, -295.4495 , -292.2401 , -294.12698, -302.85458,
# ...

# %%
features[0]
# Out:
# array([[-569.0172    , -569.0172    , -569.0172    , ..., -382.86313   ,
#         -387.4519    , -397.1328    ],
#        [   0.        ,    0.        ,    0.        , ...,  161.09453   ,
#          157.92014   ,  152.78152   ],
#        [   0.        ,    0.        ,    0.        , ...,   20.077774  ,
#           19.562817  ,   24.62673   ],
#        ...,
#        [   0.        ,    0.        ,    0.        , ...,   -2.3254871 ,
#           -2.1163745 ,    3.4122233 ],
#        [   0.        ,    0.        ,    0.        , ...,    1.3357612 ,
#            2.5092542 ,    0.59918994],
#        [   0.        ,    0.        ,    0.        , ...,   -2.4115992 ,
#            1.6777148 ,   -3.915752  ]], dtype=float32)

# %%
myarray = np.array([[1,2,3],[4,5,6]])

# to flatten the array in F-orde
arr1=features[0].flatten('F')
arr1=features[1].flatten('F')

# %%
len(arr1)
# Out:
# 1885

# %%
labels
# Out:
# ['a', 'e', 'i', 'o', 'c', 'h', 's']

# %%
features.size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 features.size
#
# AttributeError: 'list' object has no attribute 'size'

# %%
labels = np.array(labels)

# %%
len(features)
# Out:
# 56

# %%
import numpy as np



# Flatten the list of sequences into a single list of individual elements
flattened_features = [item for sublist in features for item in sublist]

# Convert the flattened list into a NumPy array
flattened_array = np.array(flattened_features)

# Print the flattened array
print(flattened_array)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 9
#       6 flattened_features = [item for sublist in features for item in sublist]
#       8 # Convert the flattened list into a NumPy array
# ----> 9 flattened_array = np.array(flattened_features)
#      11 # Print the flattened array
#      12 print(flattened_array)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (100,) + inhomogeneous part.

# %%
labels
# Out:
# array(['a', 'e', 'i', 'o', 'c', 'h', 's'], dtype='<U1')

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# %%
f = np.array(f)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 f = np.array(f)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (7, 13) + inhomogeneous part.

# %%
# Define the LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional, Dense, TimeDistributed, Dropout
from sklearn.model_selection import train_test_split

# %%
list1=[[1,9],[9,4,3]]
f=np.array(list1)
print(f)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 2
#       1 list1=[[1,9],[9,4,3]]
# ----> 2 f=np.array(list1)
#       3 print(f)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2,) + inhomogeneous part.

# %%
model = Sequential()
model.add(Bidirectional(LSTM(units=128, return_sequences=True), input_shape=(X_train.shape[1:])))
model.add(TimeDistributed(Dense(units=64, activation='relu')))
model.add(Dropout(0.3))
model.add(TimeDistributed(Dense(units=num_classes, activation='softmax')))  # num_classes is the number of output classes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 2
#       1 model = Sequential()
# ----> 2 model.add(Bidirectional(LSTM(units=128, return_sequences=True), input_shape=(X_train.shape[1:])))
#       3 model.add(TimeDistributed(Dense(units=64, activation='relu')))
#       4 model.add(Dropout(0.3))
#
# AttributeError: 'list' object has no attribute 'shape'
